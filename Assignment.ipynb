# %%
# Calculator_name 
print("AlgoZee Academy Improved Calculator")

# user_input 
number_1 = float(input("Enter First number: "))
operator = str(input("Enter operator(-, +, *, **, %, /, //): "))
number_2 = float(input("Enter Second number: "))

valid_result = True

# Use_condition 
if operator == "+":
    result = number_1 + number_2
elif operator == "-":
    result = number_1 - number_2
elif operator == "*":
    result = number_1 * number_2 
elif operator == "/":
    if  number_2 != 0:
        result = number_1 / number_2
    else:
        result = "Error: Division by zero is not allowed"
        valid_result = False
elif operator == "//":
    if number_2 != 0:
        result = number_1 // number_2
    else:
        result = "Error: Division by zero is not allowed"
        valid_result = False

elif operator == "%":
    if number_2 != 0:
        result = number_1 % number_2
    else:
        result = "Error: Division by zero is not allowed"
        valid_result = False

elif operator == "**":
    result = number_1 ** number_2
else:
    reslut = "invalid operator"
    valid_operator = False


# display output
if valid_result == True:
    print(number_1, operator, number_2, "=", result)
    if result > 0:
        print("Positive")
    elif result < 0:
        print("Negative")
    else:
        print("Zero")

else: 
    print(result)
# Out:
# AlgoZee Academy Improved Calculator
# Enter First number:  2
# Enter operator(-, +, *, **, %, /, //):  /
# Enter Second number:  2
# 2.0 / 2.0 = 1.0
# Positive

# %%
var = 23.4, 34.5, 345.5

#print(type(var))
type(var)
# Out:
# list

# %%
# name = "aleesha"

# father = "nadeem"

# print(name,father)
# Out:
# aleesha nadeem
